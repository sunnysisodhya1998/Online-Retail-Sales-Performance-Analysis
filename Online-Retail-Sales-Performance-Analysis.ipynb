# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython import get_ipython
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("online_retail.csv")
data
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 2444    536591     21398             RED POLKADOT COFFEE  MUG         1
# 2445    536591     22476     EMPIRE UNION JACK TV DINNER TRAY         2
# 2446    536591     21643         ASSORTED TUTTI FRUTTI MIRROR         3
# 2447    536591     72741                GRAND CHOCOLATECANDLE        27
# 2448    536591     21620      SET OF 4 ROSE BOTANICAL CANDLES         1
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  12-01-2010 08:26       2.55     17850.0  United Kingdom
# 1  12-01-2010 08:26       3.39     17850.0  United Kingdom
# 2  12-01-2010 08:26       2.75     17850.0  United Kingdom
# 3  12-01-2010 08:26       3.39     17850.0  United Kingdom
# 4  12-01-2010 08:26       3.39     17850.0  United Kingdom

# %%
data.tail()
# Out:
#      InvoiceNo StockCode                       Description  Quantity  \
# 2444    536591     21398          RED POLKADOT COFFEE  MUG         1
# 2445    536591     22476  EMPIRE UNION JACK TV DINNER TRAY         2
# 2446    536591     21643      ASSORTED TUTTI FRUTTI MIRROR         3
# 2447    536591     72741             GRAND CHOCOLATECANDLE        27
# 2448    536591     21620   SET OF 4 ROSE BOTANICAL CANDLES         1
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 2444  12-01-2010 16:57       2.10     14606.0  United Kingdom
# 2445  12-01-2010 16:57       4.95     14606.0  United Kingdom
# 2446  12-01-2010 16:57       1.25     14606.0  United Kingdom
# 2447  12-01-2010 16:57       1.45     14606.0  United Kingdom
# 2448  12-01-2010 16:57       3.75     14606.0  United Kingdom

# %%
data.shape
# Out:
# (2449, 8)

# %%
data.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
data.duplicated().sum()
# Out:
# 44

# %%
data=data.drop_duplicates()

# %%
data
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 2444    536591     21398             RED POLKADOT COFFEE  MUG         1
# 2445    536591     22476     EMPIRE UNION JACK TV DINNER TRAY         2
# 2446    536591     21643         ASSORTED TUTTI FRUTTI MIRROR         3
# 2447    536591     72741                GRAND CHOCOLATECANDLE        27
# 2448    536591     21620      SET OF 4 ROSE BOTANICAL CANDLES         1
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data.shape
# Out:
# (2405, 8)

# %%
data.isnull().sum()
# Out:
# InvoiceNo        0
# StockCode        0
# Description     10
# Quantity         0
# InvoiceDate      0
# UnitPrice        0
# CustomerID     542
# Country          0
# dtype: int64

# %%
data=data.drop('Description',axis=1)

# %%
data
# Out:
#      InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID  \
# 0       536365    85123A         6  12-01-2010 08:26       2.55     17850.0
# 1       536365     71053         6  12-01-2010 08:26       3.39     17850.0
# 2       536365    84406B         8  12-01-2010 08:26       2.75     17850.0
# 3       536365    84029G         6  12-01-2010 08:26       3.39     17850.0
# 4       536365    84029E         6  12-01-2010 08:26       3.39     17850.0
# ...        ...       ...       ...               ...        ...         ...
# 2444    536591     21398         1  12-01-2010 16:57       2.10     14606.0
# 2445    536591     22476         2  12-01-2010 16:57       4.95     14606.0
# 2446    536591     21643         3  12-01-2010 16:57       1.25     14606.0
# 2447    536591     72741        27  12-01-2010 16:57       1.45     14606.0
# 2448    536591     21620         1  12-01-2010 16:57       3.75     14606.0
#
#              Country
# 0     United Kingdom
# ...

# %%
data.shape
# Out:
# (2405, 7)

# %%
data['InvoiceDate']=pd.to_datetime(data['InvoiceDate'])

# %%
data
# Out:
#      InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  CustomerID  \
# 0       536365    85123A         6 2010-12-01 08:26:00       2.55     17850.0
# 1       536365     71053         6 2010-12-01 08:26:00       3.39     17850.0
# 2       536365    84406B         8 2010-12-01 08:26:00       2.75     17850.0
# 3       536365    84029G         6 2010-12-01 08:26:00       3.39     17850.0
# 4       536365    84029E         6 2010-12-01 08:26:00       3.39     17850.0
# ...        ...       ...       ...                 ...        ...         ...
# 2444    536591     21398         1 2010-12-01 16:57:00       2.10     14606.0
# 2445    536591     22476         2 2010-12-01 16:57:00       4.95     14606.0
# 2446    536591     21643         3 2010-12-01 16:57:00       1.25     14606.0
# 2447    536591     72741        27 2010-12-01 16:57:00       1.45     14606.0
# 2448    536591     21620         1 2010-12-01 16:57:00       3.75     14606.0
#
#              Country
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2405 entries, 0 to 2448
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    2405 non-null   object
#  1   StockCode    2405 non-null   object
#  2   Quantity     2405 non-null   int64
#  3   InvoiceDate  2405 non-null   datetime64[ns]
#  4   UnitPrice    2405 non-null   float64
#  5   CustomerID   1863 non-null   float64
#  6   Country      2405 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 150.3+ KB

# %%
data.describe()
# Out:
#           Quantity    UnitPrice    CustomerID
# count  2405.000000  2405.000000   1863.000000
# mean     10.383368     3.720520  15609.886205
# std      29.658810    12.560055   1853.271231
# min     -24.000000     0.000000  12431.000000
# 25%       1.000000     1.250000  14142.000000
# 50%       3.000000     2.510000  15525.000000
# 75%      10.000000     4.210000  17760.000000
# max     600.000000   569.770000  18229.000000

# %%
data.nunique()
# Out:
# InvoiceNo       137
# StockCode      1155
# Quantity         59
# InvoiceDate     115
# UnitPrice       105
# CustomerID       94
# Country           7
# dtype: int64

# %%
data['Year']=pd.DatetimeIndex(data['InvoiceDate']).year

# %%
data
# Out:
#      InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  CustomerID  \
# 0       536365    85123A         6 2010-12-01 08:26:00       2.55     17850.0
# 1       536365     71053         6 2010-12-01 08:26:00       3.39     17850.0
# 2       536365    84406B         8 2010-12-01 08:26:00       2.75     17850.0
# 3       536365    84029G         6 2010-12-01 08:26:00       3.39     17850.0
# 4       536365    84029E         6 2010-12-01 08:26:00       3.39     17850.0
# ...        ...       ...       ...                 ...        ...         ...
# 2444    536591     21398         1 2010-12-01 16:57:00       2.10     14606.0
# 2445    536591     22476         2 2010-12-01 16:57:00       4.95     14606.0
# 2446    536591     21643         3 2010-12-01 16:57:00       1.25     14606.0
# 2447    536591     72741        27 2010-12-01 16:57:00       1.45     14606.0
# 2448    536591     21620         1 2010-12-01 16:57:00       3.75     14606.0
#
#              Country  Year
# ...

# %%
Sales=data.loc[data['Quantity']>0&~(data['InvoiceNo'].str.contains('C'))]

# %%
Sales
# Out:
#      InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  CustomerID  \
# 0       536365    85123A         6 2010-12-01 08:26:00       2.55     17850.0
# 1       536365     71053         6 2010-12-01 08:26:00       3.39     17850.0
# 2       536365    84406B         8 2010-12-01 08:26:00       2.75     17850.0
# 3       536365    84029G         6 2010-12-01 08:26:00       3.39     17850.0
# 4       536365    84029E         6 2010-12-01 08:26:00       3.39     17850.0
# ...        ...       ...       ...                 ...        ...         ...
# 2444    536591     21398         1 2010-12-01 16:57:00       2.10     14606.0
# 2445    536591     22476         2 2010-12-01 16:57:00       4.95     14606.0
# 2446    536591     21643         3 2010-12-01 16:57:00       1.25     14606.0
# 2447    536591     72741        27 2010-12-01 16:57:00       1.45     14606.0
# 2448    536591     21620         1 2010-12-01 16:57:00       3.75     14606.0
#
#              Country  Year
# ...

# %%
Sales.shape
# Out:
# (2378, 8)

# %%
Sales.head()
# Out:
#   InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  CustomerID  \
# 0    536365    85123A         6 2010-12-01 08:26:00       2.55     17850.0
# 1    536365     71053         6 2010-12-01 08:26:00       3.39     17850.0
# 2    536365    84406B         8 2010-12-01 08:26:00       2.75     17850.0
# 3    536365    84029G         6 2010-12-01 08:26:00       3.39     17850.0
# 4    536365    84029E         6 2010-12-01 08:26:00       3.39     17850.0
#
#           Country  Year
# 0  United Kingdom  2010
# 1  United Kingdom  2010
# 2  United Kingdom  2010
# 3  United Kingdom  2010
# 4  United Kingdom  2010

# %%
Sales.sample(10)
# Out:
#      InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  CustomerID  \
# 1862    536544     20668         2 2010-12-01 14:32:00       0.43         NaN
# 1529    536544     22185         1 2010-12-01 14:32:00       3.36         NaN
# 2250    536569         M         1 2010-12-01 15:35:00      18.95     16274.0
# 1618    536544     22595         1 2010-12-01 14:32:00       1.66         NaN
# 1303    536532     82600        24 2010-12-01 13:24:00       2.10     12433.0
# 121     536381    37444C         1 2010-12-01 09:41:00       2.95     15311.0
# 740     536446     21156         1 2010-12-01 12:15:00       1.95     15983.0
# 1       536365     71053         6 2010-12-01 08:26:00       3.39     17850.0
# 2401    536588     22667        12 2010-12-01 16:49:00       2.95     17069.0
# 675     536415     22529         3 2010-12-01 11:57:00       0.42     12838.0
#
#              Country  Year
# 1862  United Kingdom  2010
# 1529  United Kingdom  2010
# ...

# %%
Sales_New=Sales.copy()

# %%
Sales_New['Revenue']=Sales_New['Quantity']*Sales_New['UnitPrice']

# %%
Sales_New.head()
# Out:
#   InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  CustomerID  \
# 0    536365    85123A         6 2010-12-01 08:26:00       2.55     17850.0
# 1    536365     71053         6 2010-12-01 08:26:00       3.39     17850.0
# 2    536365    84406B         8 2010-12-01 08:26:00       2.75     17850.0
# 3    536365    84029G         6 2010-12-01 08:26:00       3.39     17850.0
# 4    536365    84029E         6 2010-12-01 08:26:00       3.39     17850.0
#
#           Country  Year  Revenue
# 0  United Kingdom  2010    15.30
# 1  United Kingdom  2010    20.34
# 2  United Kingdom  2010    22.00
# 3  United Kingdom  2010    20.34
# 4  United Kingdom  2010    20.34

# %%
Sales_Mean=Sales_New.groupby('Year').mean()['Revenue']

# %%
Sales_Mean.head()
# Out:
# Year
# 2010    21.508579
# Name: Revenue, dtype: float64

# %%
Sales_Mean=Sales_Mean.reset_index()

# %%
Sales_Mean.head()
# Out:
#    Year    Revenue
# 0  2010  21.508579

# %%
plt.figure(figsize=(15,6))
sns.lineplot(Sales_Mean['Year'], Sales_Mean['Revenue'],marker='o')
plt.title('Average of Revenue per Year',fontsize=16)
plt.xlabel('Year',fontsize=12)
plt.ylabel('Average of Revenue', fontsize = 12)
plt.ylabel('Average of Revenue',fontsize=12)
plt.grid(color='darkgrey',linestyle=':',linewidth=0.5)
plt.gca().set_xticks([2009,2010,2011])
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# %%
Sales_Finish=Sales_New[Sales_New['CustomerID'].notna()]

# %%
Sales_Finish.count()
# Out:
# InvoiceNo      1837
# StockCode      1837
# Quantity       1837
# InvoiceDate    1837
# UnitPrice      1837
# CustomerID     1837
# Country        1837
# Year           1837
# Revenue        1837
# dtype: int64

# %%
Purchase_Canceled=data[data['InvoiceNo'].str.contains('C')]

# %%
Purchase_Canceled.count()
# Out:
# InvoiceNo      26
# StockCode      26
# Quantity       26
# InvoiceDate    26
# UnitPrice      26
# CustomerID     26
# Country        26
# Year           26
# dtype: int64

# %%
Count_Finished=Sales_Finish.groupby('Year').count()['InvoiceNo'].reset_index()

# %%
Count_Finished
# Out:
#    Year  InvoiceNo
# 0  2010       1837

# %%
Count_Canceled=Purchase_Canceled.groupby('Year').count()['InvoiceNo'].reset_index()
sns.lineplot(Count_Canceled['Year'],Count_Canceled['InvoiceNo'],marker='o',color='red',label='Cancel')

# %%
Count_Canceled
# Out:
#    Year  InvoiceNo
# 0  2010         26

# %%
sns.lineplot(Count_Finished['Year'],Count_Finished['InvoiceNo'],marker='o',color='green',label='Finished')

sns.lineplot(Count_Canceled['Year'],Count_Canceled['InvoiceNo'],marker='o',color='red',label='Cancel')

plt.title('Finished & Cancel',fontsize=16)

plt.xlabel('Year', fontsize=12)

plt.ylabel('InvoiceNo', fontsize=12)

plt.grid(color='darkgrey',linestyle=':',linewidth=0.5)

plt.legend()

plt.gca().set_xticks([2009,2010,2011])

plt.gca().spines['top'].set_visible(False)

plt.gca().spines['right'].set_visible(False)

# %%
Cancellation_Rate=Count_Canceled['InvoiceNo']/data['InvoiceNo'].count()*100

Cancellation=Count_Canceled.assign(Cancellation_Rate=Count_Canceled['InvoiceNo']/data['InvoiceNo'].count()*100)
Cancellation[['Year','Cancellation_Rate']]
# Out:
#    Year  Cancellation_Rate
# 0  2010           1.081081

# %%
sns.lineplot(Cancellation['Year'],Cancellation['Cancellation_Rate'],marker='o',color='red',label='Cancel')

plt.title('Cancellation Rate',fontsize=16)

plt.xlabel('Year',fontsize=12)

plt.ylabel('Cancellation',fontsize=12)

plt.grid(color='darkgrey',linestyle=':',linewidth=0.5
                                                                            )
plt.legend()

plt.gca().set_xticks([2009,2010,2011])

plt.gca().spines['top'].set_visible(False)

plt.gca().spines['right'].set_visible(False)

# %%
Comparison=Cancellation

Comparison['Total_Finished']=Count_Finished['InvoiceNo']

Comparison['Total_Canceled']=Comparison['InvoiceNo']

Comparison[['Year','Total_Finished','Total_Canceled','Cancellation_Rate']]
# Out:
#    Year  Total_Finished  Total_Canceled  Cancellation_Rate
# 0  2010            1837              26           1.081081
